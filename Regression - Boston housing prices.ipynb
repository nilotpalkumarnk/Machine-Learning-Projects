# %% [markdown]
# # Boston housing price regression dataset
# Dataset taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# Samples contain 13 attributes of houses at different locations around the Boston suburbs in the late 1970s. Targets are the median values of the houses at a location (in k$).

# %% [markdown]
# Firstly, let's select TensorFlow version 2.x in colab

# %%
# %tensorflow_version 2.x
import tensorflow
tensorflow.__version__
# Out:
# '2.4.1'

# %%
# Initialize the random number generator
import random
random.seed(0)

# Ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Import dataset
# - This dataset can be imported
# - High level API Keras has some datasets available
# - You can look at all the datasets available here https://keras.io/datasets/

# %%
from tensorflow.keras.datasets import boston_housing

# boston_housing.load_data() function returns 2 tuples, one for train data and 
# other for test data. We will take only train data here.
(features, actual_prices), _ = boston_housing.load_data(test_split=0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step

# %% [markdown]
# ### Getting details of dataset
# - We will see how many rows are there in the data
# - We will check how many features are there

# %%
print('Number of examples: ', features.shape[0])
print('Number of features for each example: ', features.shape[1])
print('Shape of actual prices data: ', actual_prices.shape)
# Out:
# Number of examples:  506
# Number of features for each example:  13
# Shape of actual prices data:  (506,)

# %%
features
# Out:
# array([[1.23247e+00, 0.00000e+00, 8.14000e+00, ..., 2.10000e+01,
#         3.96900e+02, 1.87200e+01],
#        [2.17700e-02, 8.25000e+01, 2.03000e+00, ..., 1.47000e+01,
#         3.95380e+02, 3.11000e+00],
#        [4.89822e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.75520e+02, 3.26000e+00],
#        ...,
#        [1.83377e+00, 0.00000e+00, 1.95800e+01, ..., 1.47000e+01,
#         3.89610e+02, 1.92000e+00],
#        [3.58090e-01, 0.00000e+00, 6.20000e+00, ..., 1.74000e+01,
#         3.91700e+02, 9.71000e+00],
#        [2.92400e+00, 0.00000e+00, 1.95800e+01, ..., 1.47000e+01,
#         2.40160e+02, 9.81000e+00]])

# %% [markdown]
# Let's see some values of features and labels from the dataset

# %%
features[:5]
# Out:
# array([[1.23247e+00, 0.00000e+00, 8.14000e+00, 0.00000e+00, 5.38000e-01,
#         6.14200e+00, 9.17000e+01, 3.97690e+00, 4.00000e+00, 3.07000e+02,
#         2.10000e+01, 3.96900e+02, 1.87200e+01],
#        [2.17700e-02, 8.25000e+01, 2.03000e+00, 0.00000e+00, 4.15000e-01,
#         7.61000e+00, 1.57000e+01, 6.27000e+00, 2.00000e+00, 3.48000e+02,
#         1.47000e+01, 3.95380e+02, 3.11000e+00],
#        [4.89822e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 6.31000e-01,
#         4.97000e+00, 1.00000e+02, 1.33250e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.75520e+02, 3.26000e+00],
#        [3.96100e-02, 0.00000e+00, 5.19000e+00, 0.00000e+00, 5.15000e-01,
#         6.03700e+00, 3.45000e+01, 5.98530e+00, 5.00000e+00, 2.24000e+02,
#         2.02000e+01, 3.96900e+02, 8.01000e+00],
#        [3.69311e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 7.13000e-01,
#         6.37600e+00, 8.84000e+01, 2.56710e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.91430e+02, 1.46500e+01]])

# %%
actual_prices[:5]
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7])

# %% [markdown]
# ### Build the model
# - The Sequential model is a linear stack of layers.
# - The model needs to know what input shape it should expect. For this reason, the first layer in a Sequential model (and only the first, because following layers can do automatic shape inference) needs to receive information about its input shape.
# - You can also simply add layers via the .add() method

# %%
# Initialize Sequential model
model = tensorflow.keras.models.Sequential()

# Normalize input data
model.add(tensorflow.keras.layers.BatchNormalization(input_shape=(13,)))

# Add final Dense layer for prediction - Tensorflow.keras declares weights and bias automatically
model.add(tensorflow.keras.layers.Dense(1))

# %% [markdown]
# ### Compile the model
# - Here we configure the model for training
# - We will specify an optimizer and a loss function

# %%
# Compile the model - add mean squared error as loss and stochastic gradient descent as optimizer
model.compile(optimizer='sgd', loss='mse')

# %% [markdown]
# ### Fit the model
# - .fit() trains the model for a fixed number of epochs (iterations on a dataset)
# - An epoch is an iteration over the entire x and y data provided

# %%
model.fit(features, actual_prices, epochs=100, validation_split=0.35)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 16ms/step - loss: 397.6988 - val_loss: 438.7096
# Epoch 2/100
# 11/11 [==============================] - 0s 5ms/step - loss: 75.8277 - val_loss: 142.1755
# Epoch 3/100
# 11/11 [==============================] - 0s 5ms/step - loss: 73.0797 - val_loss: 93.3884
# Epoch 4/100
# 11/11 [==============================] - 0s 4ms/step - loss: 36.5286 - val_loss: 114.0717
# Epoch 5/100
# 11/11 [==============================] - 0s 5ms/step - loss: 37.4442 - val_loss: 260.4912
# Epoch 6/100
# 11/11 [==============================] - 0s 4ms/step - loss: 36.6500 - val_loss: 54.4583
# Epoch 7/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.9884 - val_loss: 30.2246
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 35.4847 - val_loss: 28.7063
# Epoch 9/100
# 11/11 [==============================] - 0s 4ms/step - loss: 34.9403 - val_loss: 26.8549
# Epoch 10/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.0484 - val_loss: 37.4456
# Epoch 11/100
# 11/11 [==============================] - 0s 5ms/step - loss: 25.0347 - val_loss: 23.3148
# Epoch 12/100
# 11/11 [==============================] - 0s 4ms/step - loss: 25.1759 - val_loss: 26.0236
# Epoch 13/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.0858 - val_loss: 29.3833
# Epoch 14/100
# 11/11 [==============================] - 0s 5ms/step - loss: 37.6410 - val_loss: 23.8632
# Epoch 15/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.1576 - val_loss: 108.7211
# Epoch 16/100
# 11/11 [==============================] - 0s 5ms/step - loss: 41.8915 - val_loss: 34.9794
# Epoch 17/100
# 11/11 [==============================] - 0s 4ms/step - loss: 25.3313 - val_loss: 41.3652
# Epoch 18/100
# 11/11 [==============================] - 0s 4ms/step - loss: 57.6195 - val_loss: 57.2764
# Epoch 19/100
# 11/11 [==============================] - 0s 4ms/step - loss: 33.7050 - val_loss: 26.5592
# Epoch 20/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.1577 - val_loss: 35.7486
# Epoch 21/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.6869 - val_loss: 28.3239
# Epoch 22/100
# 11/11 [==============================] - 0s 5ms/step - loss: 32.7803 - val_loss: 28.1213
# Epoch 23/100
# 11/11 [==============================] - 0s 5ms/step - loss: 33.8240 - val_loss: 30.9711
# Epoch 24/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.5708 - val_loss: 26.6499
# Epoch 25/100
# 11/11 [==============================] - 0s 4ms/step - loss: 34.1704 - val_loss: 41.0234
# Epoch 26/100
# 11/11 [==============================] - 0s 4ms/step - loss: 28.4370 - val_loss: 64.9192
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 37.8764 - val_loss: 28.1942
# Epoch 28/100
# 11/11 [==============================] - 0s 4ms/step - loss: 24.6142 - val_loss: 47.5788
# Epoch 29/100
# 11/11 [==============================] - 0s 5ms/step - loss: 32.4088 - val_loss: 37.5091
# Epoch 30/100
# 11/11 [==============================] - 0s 5ms/step - loss: 32.6761 - val_loss: 26.1862
# Epoch 31/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.5859 - val_loss: 36.2206
# Epoch 32/100
# 11/11 [==============================] - 0s 5ms/step - loss: 40.2400 - val_loss: 36.8685
# Epoch 33/100
# 11/11 [==============================] - 0s 4ms/step - loss: 30.5386 - val_loss: 39.3904
# Epoch 34/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.9011 - val_loss: 33.3054
# Epoch 35/100
# 11/11 [==============================] - 0s 5ms/step - loss: 36.6691 - val_loss: 38.0853
# Epoch 36/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.8533 - val_loss: 26.7243
# Epoch 37/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.9533 - val_loss: 36.6959
# Epoch 38/100
# 11/11 [==============================] - 0s 5ms/step - loss: 28.0088 - val_loss: 33.4634
# Epoch 39/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.2573 - val_loss: 23.4051
# Epoch 40/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.0652 - val_loss: 31.8873
# Epoch 41/100
# 11/11 [==============================] - 0s 4ms/step - loss: 30.8419 - val_loss: 25.2276
# Epoch 42/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.0586 - val_loss: 41.9921
# Epoch 43/100
# 11/11 [==============================] - 0s 5ms/step - loss: 55.2725 - val_loss: 24.1378
# Epoch 44/100
# 11/11 [==============================] - 0s 4ms/step - loss: 24.5697 - val_loss: 24.5187
# Epoch 45/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.2908 - val_loss: 26.5888
# Epoch 46/100
# 11/11 [==============================] - 0s 4ms/step - loss: 30.6729 - val_loss: 24.9843
# Epoch 47/100
# 11/11 [==============================] - 0s 4ms/step - loss: 24.7258 - val_loss: 44.0113
# Epoch 48/100
# 11/11 [==============================] - 0s 4ms/step - loss: 30.8634 - val_loss: 38.6972
# Epoch 49/100
# 11/11 [==============================] - 0s 6ms/step - loss: 31.0613 - val_loss: 42.2511
# Epoch 50/100
# 11/11 [==============================] - 0s 4ms/step - loss: 25.2621 - val_loss: 89.8470
# Epoch 51/100
# 11/11 [==============================] - 0s 4ms/step - loss: 40.7338 - val_loss: 31.8134
# Epoch 52/100
# 11/11 [==============================] - 0s 5ms/step - loss: 26.0608 - val_loss: 30.5298
# Epoch 53/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.9336 - val_loss: 47.8167
# Epoch 54/100
# 11/11 [==============================] - 0s 4ms/step - loss: 36.0444 - val_loss: 31.8885
# Epoch 55/100
# 11/11 [==============================] - 0s 5ms/step - loss: 38.1798 - val_loss: 25.0897
# Epoch 56/100
# 11/11 [==============================] - 0s 5ms/step - loss: 25.8953 - val_loss: 24.2852
# Epoch 57/100
# 11/11 [==============================] - 0s 5ms/step - loss: 21.9456 - val_loss: 33.8383
# Epoch 58/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.8093 - val_loss: 40.1922
# Epoch 59/100
# 11/11 [==============================] - 0s 5ms/step - loss: 30.2844 - val_loss: 24.6122
# Epoch 60/100
# 11/11 [==============================] - 0s 5ms/step - loss: 33.5984 - val_loss: 23.8509
# Epoch 61/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.3624 - val_loss: 32.3612
# Epoch 62/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.7037 - val_loss: 24.9985
# Epoch 63/100
# 11/11 [==============================] - 0s 4ms/step - loss: 28.4304 - val_loss: 29.6590
# Epoch 64/100
# 11/11 [==============================] - 0s 4ms/step - loss: 44.0416 - val_loss: 31.6172
# Epoch 65/100
# 11/11 [==============================] - 0s 4ms/step - loss: 25.4452 - val_loss: 24.0417
# Epoch 66/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.2070 - val_loss: 40.5919
# Epoch 67/100
# 11/11 [==============================] - 0s 5ms/step - loss: 38.3055 - val_loss: 23.0480
# Epoch 68/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.6891 - val_loss: 34.7940
# Epoch 69/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.2078 - val_loss: 24.3447
# Epoch 70/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.4730 - val_loss: 23.2243
# Epoch 71/100
# 11/11 [==============================] - 0s 5ms/step - loss: 28.6031 - val_loss: 41.2262
# Epoch 72/100
# 11/11 [==============================] - 0s 5ms/step - loss: 24.3947 - val_loss: 27.2327
# Epoch 73/100
# 11/11 [==============================] - 0s 4ms/step - loss: 28.2160 - val_loss: 34.0740
# Epoch 74/100
# 11/11 [==============================] - 0s 5ms/step - loss: 34.8425 - val_loss: 29.7361
# Epoch 75/100
# 11/11 [==============================] - 0s 5ms/step - loss: 25.6547 - val_loss: 43.0812
# Epoch 76/100
# 11/11 [==============================] - 0s 5ms/step - loss: 38.2220 - val_loss: 50.2452
# Epoch 77/100
# 11/11 [==============================] - 0s 5ms/step - loss: 34.9110 - val_loss: 24.6745
# Epoch 78/100
# 11/11 [==============================] - 0s 5ms/step - loss: 32.7728 - val_loss: 38.7734
# Epoch 79/100
# 11/11 [==============================] - 0s 5ms/step - loss: 33.1622 - val_loss: 27.1350
# Epoch 80/100
# 11/11 [==============================] - 0s 4ms/step - loss: 26.8270 - val_loss: 26.5397
# Epoch 81/100
# 11/11 [==============================] - 0s 5ms/step - loss: 28.8798 - val_loss: 77.7724
# Epoch 82/100
# 11/11 [==============================] - 0s 4ms/step - loss: 55.6981 - val_loss: 46.3134
# Epoch 83/100
# 11/11 [==============================] - 0s 5ms/step - loss: 26.5152 - val_loss: 23.4724
# Epoch 84/100
# 11/11 [==============================] - 0s 5ms/step - loss: 25.4130 - val_loss: 36.6628
# Epoch 85/100
# 11/11 [==============================] - 0s 5ms/step - loss: 29.7993 - val_loss: 38.1147
# Epoch 86/100
# 11/11 [==============================] - 0s 5ms/step - loss: 36.8304 - val_loss: 24.3008
# Epoch 87/100
# 11/11 [==============================] - 0s 5ms/step - loss: 26.5140 - val_loss: 32.2188
# Epoch 88/100
# 11/11 [==============================] - 0s 5ms/step - loss: 38.5566 - val_loss: 32.3188
# Epoch 89/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.2799 - val_loss: 25.0418
# Epoch 90/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.6430 - val_loss: 38.4566
# Epoch 91/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.1420 - val_loss: 24.8120
# Epoch 92/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.5248 - val_loss: 25.5970
# Epoch 93/100
# 11/11 [==============================] - 0s 4ms/step - loss: 29.2987 - val_loss: 29.3334
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 31.5292 - val_loss: 59.6481
# Epoch 95/100
# 11/11 [==============================] - 0s 5ms/step - loss: 34.9204 - val_loss: 30.9848
# Epoch 96/100
# 11/11 [==============================] - 0s 5ms/step - loss: 28.6400 - val_loss: 30.0566
# Epoch 97/100
# 11/11 [==============================] - 0s 5ms/step - loss: 31.6271 - val_loss: 33.1651
# Epoch 98/100
# 11/11 [==============================] - 0s 5ms/step - loss: 27.2465 - val_loss: 32.2490
# Epoch 99/100
# 11/11 [==============================] - 0s 4ms/step - loss: 26.0979 - val_loss: 36.4529
# Epoch 100/100
# 11/11 [==============================] - 0s 4ms/step - loss: 27.3890 - val_loss: 28.8504

# %%
import numpy as np
test_x = np.reshape([1.2, 0, 8.14e+00, 0.0e+00, 5.3e-01, 6.14e+00, 9.170e+01, 3.97e+00, 4, 3.07e+02, 2.10e+01, 3.96e+02, 1.872e+01],(-1, 13))

test_y = model.predict(test_x)

print(test_y)
# Out:
# [[14.878177]]
