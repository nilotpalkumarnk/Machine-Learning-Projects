# %%
import numpy as np
from scipy import linalg

# %%
mat1 = np.array([[1,2,3],[4,5,6]])
mat2 = np.array([[0.5],[1.0]])

# %%
mat1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
mat2
# Out:
# array([[0.5],
#        [1. ]])

# %%
2 * mat1
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
mat1 + mat2
# Out:
# array([[1.5, 2.5, 3.5],
#        [5. , 6. , 7. ]])

# %%
mat3 = np.array([[3,2,1],[6,5,4]])

# %%
mat3
# Out:
# array([[3, 2, 1],
#        [6, 5, 4]])

# %%
mat1 + mat3
# Out:
# array([[ 4,  4,  4],
#        [10, 10, 10]])

# %%
mat4 = mat1 * mat1

# %%
mat4
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])

# %%
mat5 = mat1.dot(mat1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-60e1023c66f0> in <module>()
# ----> 1 mat5 = mat1.dot(mat1)
#
# ValueError: shapes (2,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
mat5 = mat1.dot(mat1.T)

# %%
mat5
# Out:
# array([[14, 32],
#        [32, 77]])

# %%
mat1.T.dot(mat1)
# Out:
# array([[17, 22, 27],
#        [22, 29, 36],
#        [27, 36, 45]])

# %%
mat3 = linalg.inv(mat1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-03dc918c8f4e> in <module>()
# ----> 1 mat3 = linalg.inv(mat1)
#
# /usr/local/lib/python3.7/dist-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     950     a1 = _asarray_validated(a, check_finite=check_finite)
#     951     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
# --> 952         raise ValueError('expected square matrix')
#     953     overwrite_a = overwrite_a or _datacopied(a1, a)
#     954     # XXX: I found no advantage or disadvantage of using finv.
#
# ValueError: expected square matrix

# %%
mat3 = linalg.inv(mat5)

# %%
mat3
# Out:
# array([[ 1.42592593, -0.59259259],
#        [-0.59259259,  0.25925926]])

# %%
mat5
# Out:
# array([[14, 32],
#        [32, 77]])
